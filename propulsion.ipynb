# %%
import numpy as np
import math 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
mf = [1.0000E+00,1.5000E+00,2.0000E+00,2.5000E+00,2.8000E+00,2.9000E+00,3.0000E+00,3.1000E+00,3.2000E+00,3.5000E+00,4.0000E+00,4.5000E+00,5.0000E+00,6.0000E+00,8.0000E+00,1.0000E+01]
t = [1.3025E+03,1.6879E+03,2.0128E+03,2.2714E+03,2.3730E+03,2.3892E+03,2.3951E+03,2.3928E+03,2.3851E+03,2.3480E+03,2.2741E+03,2.2001E+03,2.1292E+03,1.9979E+03,1.7753E+03,1.5962E+03]
plt.plot(mf,t)
plt.xlabel('%f', fontsize=16)
plt.ylabel('t(k)', fontsize=16)
plt.plot(mf,t, 'b', label='H2')
plt.legend(loc='upper right')

# %%
mf = [1.0000E+00,1.5000E+00,2.0000E+00,2.5000E+00,2.8000E+00,2.9000E+00,3.0000E+00,3.1000E+00,3.2000E+00,3.5000E+00,4.0000E+00,4.5000E+00,5.0000E+00,6.0000E+00,8.0000E+00,1.0000E+01]
t = [1.6159E+03,1.9738E+03,2.2801E+03,2.5403E+03,2.6570E+03,2.6742E+03,2.6763E+03,2.6687E+03,2.6561E+03,2.6081E+03,2.5218E+03,2.4384E+03,2.3597E+03,2.2162E+03,1.9771E+03,1.7866E+03]
plt.plot(mf,t)
plt.xlabel('%f', fontsize=16)
plt.ylabel('t(k)', fontsize=16)
plt.plot(mf,t, 'b', label='H2')
plt.legend(loc='upper right')

# %%
mf = [1.0000E+00,2.0000E+00,2.5000E+00,2.8000E+00,3.0000E+00,4.0000E+00,5.0000E+00,5.3000E+00,5.5000E+00,5.8000E+00,6.0000E+00,6.1000E+00,6.3000E+00,6.5000E+00,8.0000E+00,1.0000E+01]
h2 = [1.6159E+03,2.2802E+03,2.5405E+03,2.6574E+03,2.6766E+03,2.5219E+03,2.3597E+03,2.3148E+03,2.2857E+03,2.2435E+03,2.2162E+03,2.2028E+03,2.1766E+03,2.1509E+03,1.9771E+03,1.7866E+03]
meth = [1.1250E+03,1.5016E+03,1.6752E+03,1.7751E+03,1.8400E+03,2.1454E+03,2.4124E+03,2.4749E+03,2.5015E+03,2.4990E+03,2.4759E+03,2.4616E+03,2.4306E+03,2.3982E+03,2.1560E+03,1.8588E+03]
prop = [1.0979E+03,1.4561E+03,1.6231E+03,1.7199E+03,1.7830E+03,2.0825E+03,2.3527E+03,2.4249E+03,2.4688E+03,2.5238E+03,2.5482E+03,2.5550E+03,2.5561E+03,2.5430E+03,2.3349E+03,2.0514E+03]
but = [1.0934E+03,1.4482E+03,1.6140E+03,1.7100E+03,1.7728E+03,2.0709E+03,2.3409E+03,2.4136E+03,2.4584E+03,2.5163E+03,2.5448E+03,2.5546E+03,2.5625E+03,2.5553E+03,2.3564E+03,2.0740E+03]
plt.plot(mf,h2,label='H2')
plt.plot(mf,meth)
plt.plot(mf,prop)
plt.plot(mf,but)
plt.xlabel('%f', fontsize=16)
plt.ylabel('t(k)', fontsize=16)
plt.plot(mf,h2, 'b', label='H2')
plt.plot(mf, meth, 'g', label='CH4')
plt.plot(mf, prop, 'r', label='c3h8')
plt.plot(mf, but, 'y', label='c4h10')
plt.legend(loc='lower right')
