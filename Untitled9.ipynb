# %%
import numpy as npy
import math
from matplotlib import pyplot as plt

# %%
N = 50                                          # number of points
r_s = ((1/4)+(T/(3*math.sqrt(3))))*c
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

#Airfoil
a = 0.25
c = 1
T = .1
H = .02
              
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, 2*N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H
print(Zeta_c)

# plots the grid of points
size = 10
plt.figure(figsize=(size, (r_stop-r_start)/(r_stop-r_start)*size))
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.scatter(Zeta.real,Zeta.imag, s=10, color='#CD2305', marker='o', linewidth=0)
plt.scatter(Zeta.real[:,0],Zeta.imag[:,0])
#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)

# plots the grid of points
size = 10
plt.figure(figsize=(size, (r_stop-r_start)/(r_stop-r_start)*size))
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.scatter(J.real,J.imag, s=10, color='#CD2305', marker='o', linewidth=0)
plt.scatter(J.real[:,0],J.imag[:,0])
# Out:
# (-0.01924500897298753+0.04j)

# %%
gamma = 5.0
x0 = c-r , 0
x_vortex, y_vortex =0.0,0.0
x = (npy.cos(Theta) * R) +  
y = (npy.sin(Theta) * R)

# %%
def get_velocity_vortex (strength, xv, yv, R, theta):
     
    u = + strength/(2*math.pi)*(theta-yv)/((R-xv)**2+(theta-yv)**2)
    v = - strength/(2*math.pi)*(R-xv)/((R-xv)**2+(theta-yv)**2)
    
    return u, v

# %%
def get_stream_function_vortex(strength, xv, yv, R, theta):
    
    psi = strength/(4*math.pi)*numpy.log((R-xv)**2+(theta-yv)**2)
    
    return psi

# %%
# computes the velocity field on the mesh grid
u_vortex, v_vortex = get_velocity_vortex(gamma, x_vortex, y_vortex, R, theta)

# computes the stream-function on the mesh grid
psi_vortex = get_stream_function_vortex(gamma, x_vortex, y_vortex, R, theta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-0ae4959c2b14> in <module>()
#       1 # computes the velocity field on the mesh grid
# ----> 2 u_vortex, v_vortex = get_velocity_vortex(gamma, x_vortex, y_vortex, R, theta)
#       3
#       4 # computes the stream-function on the mesh grid
#       5 psi_vortex = get_stream_function_vortex(gamma, x_vortex, y_vortex, R, theta)
#
# <ipython-input-93-29a2c4db4fe2> in get_velocity_vortex(strength, xv, yv, R, theta)
#       1 def get_velocity_vortex (strength, xv, yv, R, theta):
#       2
# ----> 3     u = + strength/(2*math.pi)*(theta-yv)/((R-xv)**2+(theta-yv)**2)
#       4     v = - strength/(2*math.pi)*(R-xv)/((R-xv)**2+(theta-yv)**2)
#       5
#
# ValueError: operands could not be broadcast together with shapes (100,50) (100,)

# %%
# plots the streamlines
# %matplotlib inline

size = 10
plt.figure(figsize=(size, (theta_stop-theta_start)/(r_end-r_start)*size))
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.xlim(r_end-r_start)
plt.ylim(y_start, y_end)




plt.streamplot(X, Y, u_vortex, v_vortex, density=2, linewidth=1, arrowsize=1, arrowstyle='->')
plt.scatter(x_vortex, y_vortex, color='#CD2305', s=80, marker='o');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-989b67788bd7> in <module>()
#       3
#       4 size = 10
# ----> 5 plt.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
#       6 plt.xlabel('x', fontsize=16)
#       7 plt.ylabel('y', fontsize=16)
#
# NameError: name 'y_end' is not defined
