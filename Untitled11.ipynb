# %% [markdown]
# ## 1. To Determine the camber and thickness ratio of the airfoils you have plotted.

# %%
import numpy as npy
import math
from matplotlib import pyplot as plt

# %%
N = 50                                          # number of points

a = 0.25
c = 1
T = 0.05
H = 0.00

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, 2*N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H


#Joukoswki
Z_s = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)

# plots the grid of points
# %matplotlib inline
size = 10
plt.figure(figsize=(size, (r_stop-r_start)/(r_stop-r_start)*size))
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.scatter(Z_s.real,Z_s.imag, s=10, color='white', marker='o', linewidth=0)
plt.scatter(Z_s.real[:,0],Z_s.imag[:,0])

#Thickness and chamber
print (max(Z_s.imag[:,0]))
print (min(Z_s.imag[:,0]))
Th =  (max(Z_s.imag[:,0]))-(min(Z_s.imag[:,0]))
print ("Thickness:", (Th))
print ("camber", 0)
# Out:
# 0.0240750723738
# -0.0240750723738
# Thickness: 0.0481501447476
# camber 0

# %%
N = 50                                          # number of points

a = 0.25
c = 1
T = 0.1
H = 0.00

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, 2*N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H


#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)

# plots the grid of points
size = 10
plt.figure(figsize=(size, (r_stop-r_start)/(r_stop-r_start)*size))
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.scatter(J.real,J.imag, s=10, color='white', marker='o', linewidth=0)
plt.scatter(J.real[:,0],J.imag[:,0])

#Thickness and chamber
print (max(J.imag[:,0]))
print (min(J.imag[:,0]))
Th =  (max(J.imag[:,0]))-(min(J.imag[:,0]))
print ("Thickness:", (Th))
print ("camber", 0)
# Out:
# 0.0466046141829
# -0.0466046141829
# Thickness: 0.0932092283659
# camber 0

# %%
N = 50                                          # number of points

a = 0.25
c = 1
T = 0.3
H = 0.00

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, 2*N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H


#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)

# plots the grid of points
size = 10
plt.figure(figsize=(size, (r_stop-r_start)/(r_stop-r_start)*size))
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.scatter(J.real,J.imag, s=10, color='white', marker='o', linewidth=0)
plt.scatter(J.real[:,0],J.imag[:,0])

#Thickness and chamber
print (max(J.imag[:,0]))
print (min(J.imag[:,0]))
Th =  (max(J.imag[:,0]))-(min(J.imag[:,0]))
print ("Thickness:", (Th))
print ("camber", 0)
# Out:
# 0.125111065467
# -0.125111065467
# Thickness: 0.250222130934
# camber 0

# %%
N = 50                                          # number of points

a = 0.25
c = 1
T = 0.1
H = 0.02

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, 2*N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H


#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)

# plots the grid of points
size = 10
plt.figure(figsize=(size, (r_stop-r_start)/(r_stop-r_start)*size))
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.scatter(J.real,J.imag, s=10, color='white', marker='o', linewidth=0)
plt.scatter(J.real[:,0],J.imag[:,0])

#Thickness and chamber
print (max(J.imag[:,0]))
print (min(J.imag[:,0]))
Th =  (max(J.imag[:,0]))-(min(J.imag[:,0])) 
print ("Thickness:", (Th))
print ("camber", 0.01)
# Out:
# 0.109539276455
# -0.0133135271272
# Thickness: 0.122852803582
# camber 0.01

# %%
N = 50                                          # number of points

a = 0.25
c = 1
T = 0.1
H = 0.05

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, 2*N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H


#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)

# plots the grid of points
size = 10
plt.figure(figsize=(size, (r_stop-r_start)/(r_stop-r_start)*size))
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.scatter(J.real,J.imag, s=10, color='white', marker='o', linewidth=0)
plt.scatter(J.real[:,0],J.imag[:,0])

#Thickness and chamber
print (max(J.imag[:,0]))
print (min(J.imag[:,0]))
Th =  (max(J.imag[:,0]))-(min(J.imag[:,0]))
print ("Thickness:", (Th))
# Out:
# 0.203871274937
# -0.00178742645497
# Thickness: 0.205658701392

# %%
N = 50                                          # number of points

a = 0.25
c = 1
T = 0.1
H = 0.1

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, 2*N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H


#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)

# plots the grid of points
size = 10
plt.figure(figsize=(size, (r_stop-r_start)/(r_stop-r_start)*size))
plt.xlabel('x', fontsize=16)
plt.ylabel('y', fontsize=16)
plt.scatter(J.real,J.imag, s=10, color='white', marker='o', linewidth=0)
plt.scatter(J.real[:,0],J.imag[:,0])

#Thickness and chamber
print (max(J.imag[:,0]))
print (min(J.imag[:,0]))
Th =  (max(J.imag[:,0]))-(min(J.imag[:,0]))
print ("Thickness:", (Th))
# Out:
# 0.834970039725
# -0.0216755754543
# Thickness: 0.856645615179

# %% [markdown]
# In conformal mapping, as the thickness and camber it diverges.

# %% [markdown]
# # 2. Plot the streamlines for airfoils

# %% [markdown]
# ### T = 0.1, H = 0.02, alpha = 0

# %%
a = 0.25
c = 1
T = 0.1
H = 0.02
U = 1

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

x_start, x_stop = -1, 1              
y_start, y_stop = -1, 1   

x = npy.linspace(x_start, x_stop, N)         
y = npy.linspace(y_start, y_stop, N)

X, Y = npy.meshgrid(x,y) 
Z = X + 1j*Y

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H



#streamlines

U = 1
alpha = 0

w = U*(1-r_s**2/Z**2)+1j*Gamma/(2*math.pi*Z)
     
u = w.real
v = -w.imag

# Plot
plt.figure(figsize=(10,10))
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.scatter(Zeta_c.real,Zeta_c.imag, s=10, color='red', marker='o', linewidth=0)
plt.streamplot(X, Y, u, v, density=4.0, linewidth=1, arrowsize=2, arrowstyle='->')


#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)


w2 = ((U*(1-(r_s**2*1*Zeta_c**-2)))+(1j*Gamma/(2*math.pi*Zeta_c)))/(1-(a**2/(Zeta)**2))
u2 = w2.real
v2 = -w2.imag

# Plot
plt.figure(figsize=(10,10))
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.scatter(J.real,J.imag, s=10, color='white', marker='o', linewidth=0)
plt.streamplot(X, Y, u2, v2, density=4.0, linewidth=1, arrowsize=2, arrowstyle='->')
plt.scatter(J.real[:,0],J.imag[:,0])

# %% [markdown]
# ### T = 0.1, H = 0.02, alpha = 10

# %%
a = 0.25
c = 1
T = 0.1
H = 0.02

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

x_start, x_stop = -1, 1              
y_start, y_stop = -1, 1   

x = npy.linspace(x_start, x_stop, N)         
y = npy.linspace(y_start, y_stop, N)

X, Y = npy.meshgrid(x,y) 
Z = X + 1j*Y

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H



#streamlines
U = 1
alpha = 10

w = U*(1-r_s**2/Z**2)+1j*Gamma/(2*math.pi*Z)
     
u = w.real
v = -w.imag

# Plot
plt.figure(figsize=(10,10))
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.scatter(Zeta_c.real,Zeta_c.imag, s=10, color='red', marker='o', linewidth=0)
plt.streamplot(X, Y, u, v, density=4.0, linewidth=1, arrowsize=2, arrowstyle='->')

#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)


w2 = ((U*(1-(r_s**2*1*Zeta_c**-2)))+(1j*Gamma/(2*math.pi*Zeta_c)))/(1-(a**2/(Zeta)**2))
u2 = w2.real
v2 = -w2.imag

# Plot
plt.figure(figsize=(10,10))
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.scatter(J.real,J.imag, s=10, color='white', marker='o', linewidth=0)
plt.streamplot(X, Y, u2, v2, density=4.0, linewidth=1, arrowsize=2, arrowstyle='->')
plt.scatter(J.real[:,0],J.imag[:,0])

# %% [markdown]
# ### T = 0.1, H = 0.05, alpha = 0

# %%
a = 0.25
c = 1
T = 0.1
H = 0.05
U = 1

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

x_start, x_stop = -1, 1              
y_start, y_stop = -1, 1   

x = npy.linspace(x_start, x_stop, N)         
y = npy.linspace(y_start, y_stop, N)

X, Y = npy.meshgrid(x,y) 
Z = X + 1j*Y

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H



#streamlines

U = 1
alpha = 0

w = U*(1-r_s**2/Z**2)+1j*Gamma/(2*math.pi*Z)
     
u = w.real
v = -w.imag

# Plot
plt.figure(figsize=(10,10))
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.scatter(Zeta_c.real,Zeta_c.imag, s=10, color='red', marker='o', linewidth=0)
plt.streamplot(X, Y, u, v, density=4.0, linewidth=1, arrowsize=2, arrowstyle='->')


#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)


w2 = ((U*(1-(r_s**2*1*Zeta_c**-2)))+(1j*Gamma/(2*math.pi*Zeta_c)))/(1-(a**2/(Zeta)**2))
u2 = w2.real
v2 = -w2.imag

# Plot
plt.figure(figsize=(10,10))
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.scatter(J.real,J.imag, s=10, color='white', marker='o', linewidth=0)
plt.streamplot(X, Y, u2, v2, density=4.0, linewidth=1, arrowsize=2, arrowstyle='->')
plt.scatter(J.real[:,0],J.imag[:,0])

# %% [markdown]
# ### T = 0.1, H =0.05, alpha = 10

# %%
a = 0.25
c = 1
T = 0.1
H = 0.05
U = 1

r_s = ((1/4)+(T/(3*math.sqrt(3))))*c  
r_start, r_stop = r_s,2*r_s                         # x bounds
theta_start, theta_stop = 0, 2*math.pi               # y bounds

x_start, x_stop = -1, 1              
y_start, y_stop = -1, 1   

x = npy.linspace(x_start, x_stop, N)         
y = npy.linspace(y_start, y_stop, N)

X, Y = npy.meshgrid(x,y) 
Z = X + 1j*Y

#Airfoil
            
r = npy.linspace(r_s, 2*r_s, N)                  # x array
theta = npy.linspace(theta_start, theta_stop, N)           # y array

R, Theta = npy.meshgrid(r,theta)                      # creates grid


Zeta = (R)*npy.exp(1j*(Theta))
Zeta_c = -4*a/(3*math.sqrt(3))*T+1j*2*H



#streamlines

U = 1
alpha = 10

w = U*(1-r_s**2/Z**2)+1j*Gamma/(2*math.pi*Z)
     
u = w.real
v = -w.imag

# Plot
plt.figure(figsize=(10,10))
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.scatter(Zeta_c.real,Zeta_c.imag, s=10, color='red', marker='o', linewidth=0)
plt.streamplot(X, Y, u, v, density=4.0, linewidth=1, arrowsize=2, arrowstyle='->')


#Joukoswki
J = (Zeta+Zeta_c) + a**2/(Zeta+Zeta_c)


w2 = ((U*(1-(r_s**2*1*Zeta_c**-2)))+(1j*Gamma/(2*math.pi*Zeta_c)))/(1-(a**2/(Zeta)**2))
u2 = w2.real
v2 = -w2.imag

# Plot
plt.figure(figsize=(10,10))
plt.xlim(-1, 1)
plt.ylim(-1, 1)
plt.scatter(J.real,J.imag, s=10, color='white', marker='o', linewidth=0)
plt.streamplot(X, Y, u2, v2, density=4.0, linewidth=1, arrowsize=2, arrowstyle='->')
plt.scatter(J.real[:,0],J.imag[:,0])
