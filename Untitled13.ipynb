# %%
import numpy as np
import math 
from matplotlib import pyplot

# %%
N=100
r_start
y_start,y_stop = -6.0,6.0
x= np.linspace(x_start,x_stop,N)
y= np.linspace(y_start,y_stop,N)
X,Y = np.meshgrid(x,y)

# %%
gamma = 5.0
x_vortex,y_vortex = -1.0,0.0

# %%
def gt_vel_vortex(strength,xv,yv,X,Y):
    u = + strength/(2*math.pi)*(Y-yv)/((X-xv)**2+(Y-yv)**2)
    v = - strength/(2*math.pi)*(X-xv)/((X-xv)**2+(Y-yv)**2)
    
    return u, v

# %%
def get_stream_function_vortex(strength, xv, yv, X, Y):
    
    psi = strength/(4*math.pi)*numpy.log((X-xv)**2+(Y-yv)**2)
    
    return psi

# %%
u_vortex, v_vortex = gt_vel_vortex(gamma, x_vortex, y_vortex, X, Y)

# %%
# %matplotlib inline

size = 10
pyplot.figure(figsize=(size, (y_stop-y_start)/(x_stop-x_start)*size))
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start, x_stop)
pyplot.ylim(y_start, y_stop)




pyplot.streamplot(X, Y, u_vortex, v_vortex, density=2, linewidth=1, arrowsize=1, arrowstyle='->')
pyplot.scatter(x_vortex, y_vortex, color='#CD2305', s=80, marker='o');
