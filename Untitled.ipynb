# %%
import numpy
# %matplotlib inline
from matplotlib import pyplot as plt
x=numpy.linspace(-4,4,20)
y=x**3
plt.plot(x,y)

# %%
import math
import numpy
from matplotlib import pyplot

# %%
import numpy as np
# %matplotlib inline
import pylab as pl

# %%
N = 50                                
x_start, x_end = 0.0, 1.0            
y_start, y_end = 0.0, 1.0           
x = numpy.meshgrid(x_start, x_end, N)    
y = numpy.meshgrid(y_start, y_end, N) 
X, Y = numpy.meshgrid(x, y)

# %%
A=5
u= A*X
v= A*Y
pyplot.streamplot(X, Y, u, v)
